# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
scores_path = '/mnt/data/data-selection/data/processed/wizardlm/scores.jsonl'

# %%
with open(scores_path) as f:
    scores = [json.loads(l) for l in f]

scores = pd.DataFrame(scores)

# %%
# plot the distribution of scores['eval_score'] as histogram
sns.histplot(scores['eval_score'], bins=20)
# Out:
# <Axes: xlabel='eval_score', ylabel='Count'>
